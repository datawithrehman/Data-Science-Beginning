# %% [markdown]
# ---
# ## 📘 Author Information
#
# **👨‍💻 Name:** Abdul Rehman
# **📌 Role:** Data Science Enthusiast | Python Learner
# **📅 Notebook Created:** July 2025
#
# **🔗 Connect with Me:**
#
#
# [![LinkedIn](https://img.shields.io/badge/LinkedIn-blue?style=flat&logo=linkedin&logoColor=white)](https://www.linkedin.com/in/abdul-rehman-74b418350/)
# [![GitHub](https://img.shields.io/badge/GitHub-black?style=flat&logo=github&logoColor=white)](https://github.com/datawithrehman/Data-Science-Beginning)
# [![Twitter](https://img.shields.io/badge/Twitter-blue?style=flat&logo=twitter&logoColor=white)](https://x.com/datawithrehman)

# %% [markdown]
# # 📘 Intermediate Filtering with Pandas (Titanic Dataset)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# ✅ Load Dataset (Titanic)
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# ✅ Basic Overview
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
# ✅ Filter Rows: Passengers older than 30
df[df['age'] > 30].head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1          1       1  female  38.0      1      0  71.2833        C  First
# 3          1       1  female  35.0      1      0  53.1000        S  First
# 4          0       3    male  35.0      0      0   8.0500        S  Third
# 6          0       1    male  54.0      0      0  51.8625        S  First
# 11         1       1  female  58.0      0      0  26.5500        S  First
#
#       who  adult_male deck  embark_town alive  alone
# 1   woman       False    C    Cherbourg   yes  False
# 3   woman       False    C  Southampton   yes  False
# 4     man        True  NaN  Southampton    no   True
# 6     man        True    E  Southampton    no   True
# 11  woman       False    C  Southampton   yes   True

# %%
# ✅ Filter Rows: Females only
df[df['sex'] == 'female'].head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 8  woman       False  NaN  Southampton   yes  False
# 9  child       False  NaN    Cherbourg   yes  False

# %%
# ✅ Filter Rows: Males under 18 (Boys)
df[(df['sex'] == 'male') & (df['Age'] < 18)].head()

# %%
# ✅ OR Condition: First Class OR Survived
# Using | for OR (remember to wrap each condition in parentheses)
df[(df['pclass'] == 1) | (df['Survived'] == 1)].head()

# %%
# ✅ Complex Condition: Females in 1st class who survived
df[(df['sex'] == 'female') & (df['pclass'] == 1) & (df['survived'] == 1)].head()

# %%
# ✅ Using .query(): Clean syntax filtering
df.query("sex == 'male' and age < 18 and survived == 1").head()

# %%
# ✅ Filter by multiple values: Pclass in [1, 2]
df[df['pclass'].isin([1, 2])].head()

# %%
# ✅ Missing Data Filter: Show rows with missing Age
df[df['age'].isnull()].head()
# Out:
#     survived  pclass     sex  age  sibsp  parch     fare embarked   class  \
# 5          0       3    male  NaN      0      0   8.4583        Q   Third
# 17         1       2    male  NaN      0      0  13.0000        S  Second
# 19         1       3  female  NaN      0      0   7.2250        C   Third
# 26         0       3    male  NaN      0      0   7.2250        C   Third
# 28         1       3  female  NaN      0      0   7.8792        Q   Third
#
#       who  adult_male deck  embark_town alive  alone
# 5     man        True  NaN   Queenstown    no   True
# 17    man        True  NaN  Southampton   yes   True
# 19  woman       False  NaN    Cherbourg   yes   True
# 26    man        True  NaN    Cherbourg    no   True
# 28  woman       False  NaN   Queenstown   yes   True

# %%
# ✅ Negation (~): Passengers *not* in 3rd class
df[~(df['pclass'] == 3)].head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 11         1       1  female  58.0      0      0  26.5500        S   First
#
#       who  adult_male deck  embark_town alive  alone
# 1   woman       False    C    Cherbourg   yes  False
# 3   woman       False    C  Southampton   yes  False
# 6     man        True    E  Southampton    no   True
# 9   child       False  NaN    Cherbourg   yes  False
# 11  woman       False    C  Southampton   yes   True

# %%
# ✅ Combine Filters Step-by-Step
adults = df[df['age'] >= 18]
adults_females = adults[adults['sex'] == 'female']
adults_females.head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1          1       1  female  38.0      1      0  71.2833        C  First
# 2          1       3  female  26.0      0      0   7.9250        S  Third
# 3          1       1  female  35.0      1      0  53.1000        S  First
# 8          1       3  female  27.0      0      2  11.1333        S  Third
# 11         1       1  female  58.0      0      0  26.5500        S  First
#
#       who  adult_male deck  embark_town alive  alone
# 1   woman       False    C    Cherbourg   yes  False
# 2   woman       False  NaN  Southampton   yes   True
# 3   woman       False    C  Southampton   yes  False
# 8   woman       False  NaN  Southampton   yes  False
# 11  woman       False    C  Southampton   yes   True

# %%
# ✅ Summary: Key Techniques
# - Boolean filtering with &, |, ~
# - .isin() for list matching
# - .str.contains() for text filtering
# - .isnull() to catch missing values
# - .query() for clean expressions

# %%
df[(df['sex'] == 'male') & (df['age'] > 18)]
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3  male  22.0      1      0   7.2500        S   Third
# 4           0       3  male  35.0      0      0   8.0500        S   Third
# 6           0       1  male  54.0      0      0  51.8625        S   First
# 12          0       3  male  20.0      0      0   8.0500        S   Third
# 13          0       3  male  39.0      1      5  31.2750        S   Third
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 883         0       2  male  28.0      0      0  10.5000        S  Second
# 884         0       3  male  25.0      0      0   7.0500        S   Third
# 886         0       2  male  27.0      0      0  13.0000        S  Second
# 889         1       1  male  26.0      0      0  30.0000        C   First
# 890         0       3  male  32.0      0      0   7.7500        Q   Third
#
#      who  adult_male deck  embark_town alive  alone
# ...
