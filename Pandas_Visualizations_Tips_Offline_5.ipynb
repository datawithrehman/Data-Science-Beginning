# %% [markdown]
# ---
# ## 📘 Author Information
#
# **👨‍💻 Name:** Abdul Rehman
# **📌 Role:** Data Science Enthusiast | Python Learner
# **📅 Notebook Created:** July 2025
#
# **🔗 Connect with Me:**
#
#
# [![LinkedIn](https://img.shields.io/badge/LinkedIn-blue?style=flat&logo=linkedin&logoColor=white)](https://www.linkedin.com/in/abdul-rehman-74b418350/)
# [![GitHub](https://img.shields.io/badge/GitHub-black?style=flat&logo=github&logoColor=white)](https://github.com/datawithrehman/Data-Science-Beginning)
# [![Twitter](https://img.shields.io/badge/Twitter-blue?style=flat&logo=twitter&logoColor=white)](https://x.com/datawithrehman)

# %% [markdown]
# # 📊 Visualizing Data with Pandas (Using `tips` Dataset)
#
# Welcome! In this notebook, we’ll learn how to use **pandas** for quick and easy visualizations using the famous `tips` dataset from seaborn.
#
# *You don't need to be a plotting expert — just a few lines of code will do the job.*

# %%
# Import necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 📥 Load the Dataset
#
# We'll use the built-in `tips` dataset, which contains information about restaurant tips.

# %%
# Load tips dataset (requires internet access)
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## 📈 Line Plot
#
# Let’s create a basic line plot of total bills.

# %%
df['total_bill'].plot(title='Total Bill Trend', figsize=(10, 5))
plt.xlabel('Index')
plt.ylabel('Total Bill')
plt.grid(True)
plt.show()

# %% [markdown]
# ## 📊 Bar Plot
#
# Now let’s see the average tip per day.

# %%
df.groupby('day')['tip'].mean().plot(kind='bar', color='skyblue', title='Average Tip by Day')
plt.ylabel('Average Tip ($)')
plt.xlabel('Day')
plt.grid(axis='y')
plt.show()
# Out:
# C:\Users\Abdul Rehman\AppData\Local\Temp\ipykernel_2812\1779221968.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('day')['tip'].mean().plot(kind='bar', color='skyblue', title='Average Tip by Day')

# %% [markdown]
# ## 📉 Histogram
#
# Visualize the distribution of total bills using a histogram.

# %%
df['total_bill'].plot(kind='hist', bins=20, color='salmon', title='Distribution of Total Bill')
plt.xlabel('Total Bill ($)')
plt.show()

# %% [markdown]
# ## 💾 Save Your Plot
#
# You can also save your plot as an image.

# %%
plot = df.groupby('day')['total_bill'].sum().plot(kind='bar', color='orange', title='Total Sales by Day')
plt.ylabel('Total Bill ($)')
plt.xlabel('Day')
plt.tight_layout()
plt.savefig('total_sales_by_day.png')
plt.show()
# Out:
# C:\Users\Abdul Rehman\AppData\Local\Temp\ipykernel_2812\2980588736.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   plot = df.groupby('day')['total_bill'].sum().plot(kind='bar', color='orange', title='Total Sales by Day')

# %% [markdown]
# ##  Summary
#
# - Pandas makes quick visualizations easy and effective.
# - Great for exploring trends, comparisons, and distributions.
# - Perfect for fast insights in EDA.
